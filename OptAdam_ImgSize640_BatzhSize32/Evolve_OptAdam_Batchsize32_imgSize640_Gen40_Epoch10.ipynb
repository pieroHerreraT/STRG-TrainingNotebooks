# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt

import torch
import utils
import cv2
import matplotlib.pyplot as plt
import ipywidgets as widgets
from ipywidgets import interact
display = utils.notebook_init()
# Out:
# INFO:yolov5:YOLOv5 🚀 v6.2-208-g8236d88 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
# YOLOv5 🚀 v6.2-208-g8236d88 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 22.9/78.2 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/TP1 Notebooks/train_data.zip" -d "/content/"
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#   inflating: /content/train_data/labels/train/ME_Cielo_2.5L_0391.txt
#   inflating: /content/train_data/labels/train/ME_Cielo_2.5L_0392.txt
#   inflating: /content/train_data/labels/train/ME_Cielo_2.5L_0393.txt
#   inflating: /content/train_data/labels/train/ME_Cielo_2.5L_0394.txt
#   inflating: /content/train_data/labels/train/ME_Cielo_2.5L_0395.txt
#   inflating: /content/train_data/labels/train/ME_Cielo_2.5L_0396.txt
#   inflating: /content/train_data/labels/train/ME_Cielo_2.5L_0397.txt
#   inflating: /content/train_data/labels/train/ME_Cielo_2.5L_0398.txt
#   inflating: /content/train_data/labels/train/ME_Cielo_2.5L_0399.txt
#   inflating: /content/train_data/labels/train/ME_Cielo_2.5L_0400.txt
#   inflating: /content/train_data/labels/train/ME_Cielo_2.5L_0401.txt
#   inflating: /content/train_data/labels/train/ME_Cielo_2.5L_0402.txt
#   inflating: /content/train_data/labels/train/ME_Cielo_2.5L_0403.txt
# ...

# %%
PATH_DATA = 'train_data'
PATH_TRAIN = 'train_data/images/train/'
PATH_VAL   = 'train_data/images/val/'
PATH_TEST  = 'train_data/images/test/'
N_CLASSES  = 12
CLASS_NAMES = ['IncaKola_1.5L', 'SanMateo_2.5L', 'Cielo_2.5L', 'MonsterOriginal_473ml', 'MonsterZeroSugar_473ml',
               'RedBull_250ml', 'ME_IncaKola_1.5L', 'ME_SanMateo_2.5L', 'ME_Cielo_2.5L', 'ME_MonsterOriginal_473ml','ME_MonsterZeroSugar_473ml','ME_RedBull_250ml']

f = open('/content/yolov5/data/products.yaml','w+')

f.write('path: ../'+PATH_DATA+'\n')
f.write('train: ../'+PATH_TRAIN+'\n')
f.write('val:   ../'+PATH_VAL+'\n')
f.write('nc:  '+str(N_CLASSES)+'\n')
f.write('names:  '+str(CLASS_NAMES)+'\n')

f.close()

# %%
# !python train.py --imgsz 640 --batch 32 --epochs 10 --data '/content/yolov5/data/products.yaml' --weights 'yolov5s.pt' --cache --evolve 40 --optimizer Adam
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/data/products.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=40, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=Adam, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-208-g8236d88 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...
